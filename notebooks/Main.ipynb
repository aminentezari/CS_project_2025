# %% [markdown]
# **This part id for importing the libraries that i need for this project**

# %%
import pandas as pd

# %% [markdown]
# **Here is the name of the fils that included in Dataset.**

# %%
files = [
    "CAvideos.csv",
    "DEvideos.csv",
    "FRvideos.csv",
    "GBvideos.csv",
    "INvideos.csv",
    "JPvideos.csv",
    "KRvideos.csv",
    "MXvideos.csv",
    "RUvideos.csv",
    "USvideos.csv"
]

# %% [markdown]
# **1. Create a single dataframe with the concatenation of all input csv files, adding a column called country**

# %%
overall = []

# %%
for file in files:
    
    df_temp = pd.read_csv("../data/" + file, encoding="utf-8",encoding_errors="replace")
    
    country = file[:2]   #extract to first character of file name 
    
    df_temp["country"] = country
    
    overall.append(df_temp)
    
    
df = pd.concat(overall, ignore_index= True)   #we put true because each df start with index 0

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')

# %%
df["country"].unique()
# Out:
# array(['CA', 'DE', 'FR', 'GB', 'IN', 'JP', 'KR', 'MX', 'RU', 'US'],
#       dtype=object)

# %% [markdown]
# **2. Extract all videos that have no tag.**

# %%
df["tags"].isna().sum()
# Out:
# np.int64(0)

# %%
no_tag = df[df["tags"]== "[none]"]

# %%
no_tag
# Out:
#            video_id trending_date  \
# 41      JwboxqDylgg      17.14.11
# 58      9B-q8h31Bpk      17.14.11
# 78      1UE5Dq1rvUA      17.14.11
# 86      pmJQ4KwliX4      17.14.11
# 98      lHcXhBojpeQ      17.14.11
# ...             ...           ...
# 375815  VGykknw9eCM      18.14.06
# 375819  fAIX12F6958      18.14.06
# 375865  gS1DbvHHVH0      18.14.06
# 375873  E4c7EE8_IX0      18.14.06
# 375938  1h7KV2sjUWY      18.14.06
#
#                                                     title       channel_title  \
# 41      Canada Soccer's Women's National Team v USA In...       Canada Soccer
# 58      John Oliver Tackles Louis C.K. And Donald Trum...            TV Shows
# 78                Taylor Swift Perform Ready For It - SNL          Ken Reactz
# 86      LATEST Q POSTS: ROTHSCHILDS, HOUSE OF SAUD, lL...        James Munder
# 98                       三屆TVB視帝，拋棄10年青梅竹馬髮妻，為娶小三還不惜與母絕交！               明星百曉生
# ...                                                   ...                 ...
# 375815  Made Defiant: The Mixtape ft. Neymar Jr., Kane...        Beats by Dre
# 375819  Bumblebee (2018) - Official Teaser Trailer - P...  Paramount Pictures
# 375865                          Going in to brain surgery       Simone Giertz
# 375873                                    Weezer - Africa              weezer
# 375938                         True Facts : Ant Mutualism            zefrank1
#
#         category_id              publish_time    tags     views   likes  \
# 41               17  2017-11-13T05:53:49.000Z  [none]     36311     277
# 58               22  2017-11-13T04:49:26.000Z  [none]    106029    1270
# 78               24  2017-11-12T05:18:02.000Z  [none]    320964    8069
# 86                2  2017-11-12T21:25:40.000Z  [none]    116820    1503
# 98               22  2017-11-12T12:49:50.000Z  [none]     88061      47
# ...             ...                       ...     ...       ...     ...
# 375815           10  2018-06-07T07:01:06.000Z  [none]   3577614   12318
# 375819            1  2018-06-05T07:00:01.000Z  [none]  19864779  228670
# 375865           28  2018-05-30T14:22:13.000Z  [none]   1635301  120791
# 375873           10  2018-05-29T12:00:11.000Z  [none]   4682557  115240
# 375938           22  2018-05-18T01:00:06.000Z  [none]   1064798   60008
#
#         dislikes  comment_count  \
# 41            28             13
# 58           101            181
# 78           285            717
# 86           139           1066
# 98            58             17
# ...          ...            ...
# 375815      1345           1414
# 375819     16420          46318
# 375865      1098          20711
# 375873      5069           9170
# 375938       382           3936
#
#                                         thumbnail_link  comments_disabled  \
# 41      https://i.ytimg.com/vi/JwboxqDylgg/default.jpg              False
# 58      https://i.ytimg.com/vi/9B-q8h31Bpk/default.jpg              False
# 78      https://i.ytimg.com/vi/1UE5Dq1rvUA/default.jpg              False
# 86      https://i.ytimg.com/vi/pmJQ4KwliX4/default.jpg              False
# 98      https://i.ytimg.com/vi/lHcXhBojpeQ/default.jpg              False
# ...                                                ...                ...
# 375815  https://i.ytimg.com/vi/VGykknw9eCM/default.jpg              False
# 375819  https://i.ytimg.com/vi/fAIX12F6958/default.jpg              False
# 375865  https://i.ytimg.com/vi/gS1DbvHHVH0/default.jpg              False
# 375873  https://i.ytimg.com/vi/E4c7EE8_IX0/default.jpg              False
# 375938  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 41                 False                   False
# 58                 False                   False
# 78                 False                   False
# 86                 False                   False
# 98                 False                   False
# ...                  ...                     ...
# 375815             False                   False
# 375819             False                   False
# 375865             False                   False
# 375873             False                   False
# 375938             False                   False
#
#                                               description country
# 41      Canada Soccer's Women's National Team face riv...      CA
# 58                      John Oliver on News, Politics ...      CA
# 78      Thanks for watching please subscribe and subsc...      CA
# 86      https://pastebin.ca/3930472\n\nSupport My Chan...      CA
# 98                                                    NaN      CA
# ...                                                   ...     ...
# 375815  When your time comes, you have two choices. Yo...      US
# 375819  Every adventure has a beginning. Watch the off...      US
# 375865  We’ll post an update on Instagram and Twitter ...      US
# 375873  Stream + download the song: http://fanlink.to/...      US
# 375938                                                NaN      US
#
# [37698 rows x 17 columns]

# %% [markdown]
# **3. For each channel, determine the total number of views**

# %%
df.groupby('channel_title')['views'].sum()
# Out:
# channel_title
# ! 세상에 무슨일이                3942977
# !!8時だよ面白ネタ大集合               50207
# !BTS・TWICE まとめ               7310
# !Los amorosos Virales¡       6069
# !t Live                    240038
#                            ...
# ５分でできる DIY                 272607
# ＢＡＳＨｔｖ                     116292
# Ｋのフィッシングちゃんねる               37165
# ＷＡＪＯＩＫＡ                    424129
# 💜Sandrea                   347155
# Name: views, Length: 37824, dtype: int64

# %% [markdown]
# **4. Save all rows with disabled comments and disabled ratings, or that have video_error_or_removed in a new dataframe called excluded, and remove those rows from the original dataframe.**

# %%
excluded = df[((df['comments_disabled'] == True) & (df['ratings_disabled'] == True)) | (df['video_error_or_removed'] == True)]

# %%
excluded.count()
# Out:
# video_id                  2620
# trending_date             2620
# title                     2620
# channel_title             2620
# category_id               2620
# publish_time              2620
# tags                      2620
# views                     2620
# likes                     2620
# dislikes                  2620
# comment_count             2620
# thumbnail_link            2620
# comments_disabled         2620
# ratings_disabled          2620
# video_error_or_removed    2620
# description               2307
# country                   2620
# dtype: int64

# %%
df = df.drop(excluded.index)

# %%
df[((df['comments_disabled'] == True) & (df['ratings_disabled'] == True)) | (df['video_error_or_removed'] == True)]
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description, country]
# Index: []

# %% [markdown]
# **5. Add a like_ratio column storing the ratio between the number of likes and of dislikes**

# %%
df["like_ratio"] = df['likes'] / df['dislikes'].replace(0,1)

# %%
df['like_ratio']
# Out:
# 0          18.135076
# 1          75.707346
# 2          27.352500
# 3          66.485168
# 4          77.513044
#              ...
# 375937     27.552347
# 375938    157.089005
# 375939     46.577519
# 375940     67.799368
# 375941      1.676616
# Name: like_ratio, Length: 375942, dtype: float64

# %% [markdown]
# **6. Cluster the publish time into 10-minute intervals (e.g. from 02:20 to 02:30)**

# %%
df["publish_time"].dtype
# Out:
# dtype('O')

# %%
df["publish_time"] = pd.to_datetime(df["publish_time"])  #convert them into proper data farame format

# %%
df["publish_time"].dt.minute
# Out:
# 0          0
# 1          0
# 2          5
# 3          1
# 4          4
#           ..
# 375937     0
# 375938     0
# 375939    34
# 375940     0
# 375941     9
# Name: publish_time, Length: 375942, dtype: int32

# %%
df["cluster"] = (df["publish_time"].dt.minute + df["publish_time"].dt.hour * 60) // 10  #for removing decimals

# %%
df.head(15)
# Out:
#        video_id trending_date  \
# 0   n1WpP7iowLc      17.14.11
# 1   0dBIkQ4Mz1M      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   d380meD0W0M      17.14.11
# 4   2Vv-BfVoq4g      17.14.11
# 5   0yIWz1XEeyc      17.14.11
# 6   _uM5kFfkhB8      17.14.11
# 7   2kyS6SvSYSE      17.14.11
# 8   JzCsM1vtn78      17.14.11
# 9   43sm-QwLcx4      17.14.11
# 10  H1KBHFXm2Bg      17.14.11
# 11  U3xLOo-CNwo      17.14.11
# 12  FyZMnhUtLfE      17.14.11
# 13  7MxiQ4v0EnE      17.14.11
# 14  LUzsOyWp9lw      17.14.11
#
#                                                 title     channel_title  \
# 0          Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                       PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                            I Dare You: GOING BALD!?          nigahiga
# 4         Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# 5   Jake Paul Says Alissa Violet CHEATED with LOGA...        DramaAlert
# 6              Vanoss Superhero School - New Students      VanossGaming
# 7                  WE WANT TO TALK ABOUT OUR MARRIAGE      CaseyNeistat
# 8                THE LOGANG MADE HISTORY. LOL. AGAIN.  Logan Paul Vlogs
# 9   Finally Sheldon is winning an argument about t...       Sheikh Musa
# 10    21 Savage - Bank Account (Official Music Video)         21 Savage
# 11  12 Weird Ways To Sneak Food Into Class / Back ...       Troom Troom
# 12         猎场 | Game Of Hunting 12【TV版】（胡歌、張嘉譯、祖峰等主演）              大劇獨播
# 13  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...     Speed Records
# 14  YOUTUBERS REACT TO TOP 10 TWITTER ACCOUNTS OF ...               FBE
#
#     category_id              publish_time  \
# 0            10 2017-11-10 17:00:03+00:00
# 1            23 2017-11-13 17:00:00+00:00
# 2            23 2017-11-12 19:05:24+00:00
# 3            24 2017-11-12 18:01:41+00:00
# 4            10 2017-11-09 11:04:14+00:00
# 5            25 2017-11-13 07:37:51+00:00
# 6            23 2017-11-12 23:52:13+00:00
# 7            22 2017-11-13 17:13:01+00:00
# 8            24 2017-11-12 20:19:24+00:00
# 9            22 2017-11-10 14:10:46+00:00
# 10           10 2017-11-10 19:00:02+00:00
# 11           26 2017-11-12 15:00:05+00:00
# 12            1 2017-11-12 16:00:01+00:00
# 13           10 2017-11-11 16:41:15+00:00
# 14           24 2017-11-12 22:00:01+00:00
#
#                                                  tags     views    likes  \
# 0   Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1   plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2   racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3   ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4   edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
# 5   #DramaAlert|"Drama"|"Alert"|"DramaAlert"|"keem...   1309699   103755
# 6   Funny Moments|"Montage video games"|"gaming"|"...   2987945   187464
# 7                                     SHANtell martin    748374    57534
# 8   logan paul vlog|"logan paul"|"logan"|"paul"|"o...   4477587   292837
# 9                God|"Sheldon Cooper"|"Young Sheldon"    505161     4135
# 10  21 savage|"bank account"|"21 savage bank accou...   5068229   263596
# 11  sneak food|"how to sneak food into class"|"cla...   3153224    28451
# 12  電視劇|"大陸電視劇"|"猎场"|"职场"|"商战"|"爱情"|"都市"|"胡歌"|"陈龙"...    158815      218
# 13  punjabi songs|"punjabi bhangra"|"punjabi music...   5718766   127477
# 14  twitter|"top 10"|"Taylor Swift"|"YOUTUBERS REA...    960747    31810
#
#     dislikes  comment_count                                  thumbnail_link  \
# 0      43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1       1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2       5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4      21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
# 5       4613          12143  https://i.ytimg.com/vi/0yIWz1XEeyc/default.jpg
# 6       9850          26629  https://i.ytimg.com/vi/_uM5kFfkhB8/default.jpg
# 7       2967          15959  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 8       4123          36391  https://i.ytimg.com/vi/JzCsM1vtn78/default.jpg
# 9        976           1484  https://i.ytimg.com/vi/43sm-QwLcx4/default.jpg
# 10      8585          28976  https://i.ytimg.com/vi/H1KBHFXm2Bg/default.jpg
# 11      2285           3312  https://i.ytimg.com/vi/U3xLOo-CNwo/default.jpg
# 12        30            186  https://i.ytimg.com/vi/FyZMnhUtLfE/default.jpg
# 13      7134           8063  https://i.ytimg.com/vi/7MxiQ4v0EnE/default.jpg
# 14       668           5335  https://i.ytimg.com/vi/LUzsOyWp9lw/default.jpg
#
#     comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
# 5               False             False                   False
# 6               False             False                   False
# 7               False             False                   False
# 8               False             False                   False
# 9               False             False                   False
# 10              False             False                   False
# 11              False             False                   False
# 12              False             False                   False
# 13              False             False                   False
# 14              False             False                   False
#
#                                           description country  like_ratio  \
# 0   Eminem's new track Walk on Water ft. Beyoncé i...      CA   18.135076
# 1   STill got a lot of packages. Probably will las...      CA   75.707346
# 2   WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...      CA   27.352500
# 3   I know it's been a while since we did this sho...      CA   66.485168
# 4   🎧: https://ad.gt/yt-perfect\n💰: https://atlant...      CA   77.513044
# 5   ► Follow for News! - https://twitter.com/KEEMS...      CA   22.491871
# 6   Vanoss Merch Shop: https://vanoss.3blackdot.co...      CA   19.031878
# 7   SHANTELL'S CHANNEL - https://www.youtube.com/s...      CA   19.391304
# 8   Join the movement. Be a Maverick ► https://Sho...      CA   71.025224
# 9   Sheldon is roasting pastor of the church\nyoun...      CA    4.236680
# 10  Watch the official music video of Bank Account...      CA   30.704252
# 11  Subscribe Here: http://bit.ly/2uaz0on\n12 Hot ...      CA   12.451204
# 12  Thanks for watching the drama! Help more peopl...      CA    7.266667
# 13  Song - Daang\nSinger - Mankirt Aulakh\nFaceboo...      CA   17.868937
# 14  CLICK TO SUBSCRIBE TO THE YOUTUBERS IN THIS EP...      CA   47.619760
#
#     cluster                                           tag_list
# 0       102  [Eminem, "Walk", "On", "Water", "Aftermath/Sha...
# 1       102  [plush, "bad unboxing", "unboxing", "fan mail"...
# 2       114  [racist superman, "rudy", "mancuso", "king", "...
# 3       108  [ryan, "higa", "higatv", "nigahiga", "i dare y...
# 4        66  [edsheeran, "ed sheeran", "acoustic", "live", ...
# 5        45  [#DramaAlert, "Drama", "Alert", "DramaAlert", ...
# 6       143  [Funny Moments, "Montage video games", "gaming...
# 7       103                                  [SHANtell martin]
# 8       121  [logan paul vlog, "logan paul", "logan", "paul...
# 9        85           [God, "Sheldon Cooper", "Young Sheldon"]
# 10      114  [21 savage, "bank account", "21 savage bank ac...
# 11       90  [sneak food, "how to sneak food into class", "...
# 12       96  [電視劇, "大陸電視劇", "猎场", "职场", "商战", "爱情", "都市", "...
# 13      100  [punjabi songs, "punjabi bhangra", "punjabi mu...
# 14      132  [twitter, "top 10", "Taylor Swift", "YOUTUBERS...

# %% [markdown]
# **7. For each interval, determine the number of videos, average number of likes and of dislikes.**

# %%
df.groupby("cluster").size()
# Out:
# cluster
# 0      2913
# 1      1522
# 2      1248
# 3      1625
# 4      1283
#        ...
# 139    1571
# 140    1464
# 141    1679
# 142    1480
# 143    1279
# Length: 144, dtype: int64

# %%
df.groupby("cluster").agg(
    videos_count = ("video_id", "count"),
    avg_likes = ("likes", "mean"),
    avg_dislikes = ("dislikes", "mean")
)
# Out:
#          videos_count     avg_likes  avg_dislikes
# cluster
# 0                2913  60951.483350   3787.232750
# 1                1522  22553.870565   1437.457293
# 2                1248  21258.370192   1066.330128
# 3                1625  36604.352000    949.439385
# 4                1283  41770.614186   1889.012471
# ...               ...           ...           ...
# 139              1571  22537.293444   1098.155315
# 140              1464  30151.353825   1156.117486
# 141              1679  18018.572365    867.416319
# 142              1480  45303.938514   9253.183784
# 143              1279  10768.882721    501.747459
#
# [144 rows x 3 columns]

# %% [markdown]
# **8. For each tag, determine the number of videos**

# %% [markdown]
# we consider 'none' as a tag and dont excluded from dataset

# %% [markdown]
# df_exploded = df_exploded[df_exploded["tag_list"] != "[none]"]

# %%
df["tags"].head(20)
# Out:
# 0     Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# 1     plush|"bad unboxing"|"unboxing"|"fan mail"|"id...
# 2     racist superman|"rudy"|"mancuso"|"king"|"bach"...
# 3     ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
# 4     edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# 5     #DramaAlert|"Drama"|"Alert"|"DramaAlert"|"keem...
# 6     Funny Moments|"Montage video games"|"gaming"|"...
# 7                                       SHANtell martin
# 8     logan paul vlog|"logan paul"|"logan"|"paul"|"o...
# 9                  God|"Sheldon Cooper"|"Young Sheldon"
# 10    21 savage|"bank account"|"21 savage bank accou...
# 11    sneak food|"how to sneak food into class"|"cla...
# 12    電視劇|"大陸電視劇"|"猎场"|"职场"|"商战"|"爱情"|"都市"|"胡歌"|"陈龙"...
# 13    punjabi songs|"punjabi bhangra"|"punjabi music...
# 14    twitter|"top 10"|"Taylor Swift"|"YOUTUBERS REA...
# 15    buzzfeed|"buzzfeedblue"|"outsmarted"|"outsmart...
# 16        prank|"pranks"|"nelk"|"nelkfilmz"|"nelkfilms"
# 17    Graham Norton|"Graham Norton Show Official"|"E...
# 18    Rooster Teeth|"RT"|"animation"|"television"|"f...
# 19    sharry mann|"sharry mann new song"|"sharry man...
# Name: tags, dtype: object

# %%
df["tag_list"] = df["tags"].str.split("|")

# %%
df_exploded = df.explode("tag_list")  #turns each element of list into row

# %%
df_exploded["tag_list"].value_counts()
# Out:
# tag_list
# [none]                                     37698
# "funny"                                    14969
# "comedy"                                   11967
# "2018"                                     11047
# "news"                                      6004
#                                            ...
# "BALD NEUER ALIEN UND TOMATENKOPF SKIN"        1
# "NEUER ALIEN UND TOMATENKOPF SKIN"             1
# "Neuer 50 VS 50 MODUS COMEBACK"                1
# "NEUER ALIEN SKIN IST DA!"                     1
# "langford"                                     1
# Name: count, Length: 891167, dtype: int64

# %% [markdown]
# **9. Find the tags with the largest number of videos**

# %%
tags_count = df_exploded["tag_list"].value_counts()

# %%
tags_count.idxmax()
# Out:
# '[none]'

# %% [markdown]
# If we want to dont consider none as a tag so the largest number is:

# %%
tag_count_r = tags_count.drop("[none]")

# %%
tag_count_r.idxmax()
# Out:
# '"funny"'

# %% [markdown]
# **10. For each (tag, country) pair, compute average ratio likes/dislikes**

# %%
df_exploded["average_ratio"] = df_exploded["likes"] / df_exploded["dislikes"].replace(0,1)

# %%
df_exploded.groupby(["tag_list", "country"])["average_ratio"].mean().reset_index()
# Out:
#                                                   tag_list country  \
# 0                                                               CA
# 1                                                               DE
# 2                                                               FR
# 3                                                               IN
# 4                                                               JP
# ...                                                    ...     ...
# 1141776                                        ＴＨＥカラオケ★バトル      JP
# 1141777                                                ｓ１３      JP
# 1141778  🍊 Exatlón México 🍉 programa 🍒 88 EP4-👢 14/02/2...      MX
# 1141779              🔥BROMA A FALCONY EL SUSTO DE SU VIDA🔥      MX
# 1141780                                🚀 smartpixel.com.ua      RU
#
#          average_ratio
# 0             8.618739
# 1            24.344225
# 2            16.424636
# 3             7.104845
# 4             9.894877
# ...                ...
# 1141776       7.450000
# 1141777      15.335714
# 1141778       5.750000
# 1141779     128.516035
# 1141780       0.714286
#
# [1141781 rows x 3 columns]

# %% [markdown]
# **11. For each (trending_date, country) pair, the video with the largest number of views**

# %%
idx = df.groupby(['trending_date', 'country'])['views'].idxmax()

# %%
df.loc[idx, ['trending_date', 'country', 'video_id', 'title', 'channel_title', 'views']].reset_index()
# Out:
#        index trending_date country     video_id  \
# 0       3398      17.01.12      CA  6ZfuNTqbHE8
# 1      44280      17.01.12      DE  6ZfuNTqbHE8
# 2      85252      17.01.12      FR  3VbHg5fqBYw
# 3     126032      17.01.12      GB  TyHvyGVs42U
# 4     164617      17.01.12      IN  6ZfuNTqbHE8
# ...      ...           ...     ...          ...
# 1962  216792      18.31.05      JP  aJOTlE1K90k
# 1963  251198      18.31.05      KR  ntWSnDV0MYs
# 1964  291483      18.31.05      MX  xTlNMmZKwpA
# 1965  332058      18.31.05      RU  1nX0kF2UwDc
# 1966  373139      18.31.05      US  VYOjWnS4cMY
#
#                                                   title         channel_title  \
# 0     Marvel Studios' Avengers: Infinity War Officia...  Marvel Entertainment
# 1     Marvel Studios' Avengers: Infinity War Officia...  Marvel Entertainment
# 2                  Avengers: Infinity War Trailer Tease  Marvel Entertainment
# 3             Luis Fonsi, Demi Lovato - Échame La Culpa         LuisFonsiVEVO
# 4     Marvel Studios' Avengers: Infinity War Officia...  Marvel Entertainment
# ...                                                 ...                   ...
# 1962              Maroon 5 - Girls Like You ft. Cardi B           Maroon5VEVO
# 1963                     [MV] AOA _ Bingle Bangle(빙글뱅글)          1theK (원더케이)
# 1964  Cardi B, Bad Bunny & J Balvin - I Like It [Off...               Cardi B
# 1965  [BadComedian] - Движение Вверх (Плагиат или ве...           BadComedian
# 1966  Childish Gambino - This Is America (Official V...   ChildishGambinoVEVO
#
#           views
# 0      56367282
# 1      56367282
# 2       7281189
# 3     143408235
# 4      56367282
# ...         ...
# 1962    3057987
# 1963    4150448
# 1964   20723565
# 1965    3125598
# 1966  217750076
#
# [1967 rows x 7 columns]

# %% [markdown]
# **12. Divide trending_date into three columns: year, month, day**

# %%
df["trending_date"].dtype
# Out:
# dtype('O')

# %%
df["trending_date"]
# Out:
# 0         17.14.11
# 1         17.14.11
# 2         17.14.11
# 3         17.14.11
# 4         17.14.11
#             ...
# 751879    18.14.06
# 751880    18.14.06
# 751881    18.14.06
# 751882    18.14.06
# 751883    18.14.06
# Name: trending_date, Length: 746644, dtype: object

# %%
df[['year', 'day', 'month']] = df['trending_date'].str.split('.', expand = True)

# %% [markdown]
# ### This is done by string but there is way also for the converting into datetime

# %%
df["trending_date"] = pd.to_datetime(df["trending_date"], format="%y.%d.%m")

# %%
df["year"] = df["trending_date"].dt.year
df["month"] = df["trending_date"].dt.month
df["day"] = df["trending_date"].dt.day

# %% [markdown]
# **13. For each (month, country) pair, the video with the largest number of views**

# %%
idxx = df.groupby(['month', 'country'])['views'].idxmax()

# %%
df.loc[idxx, ['month', 'country', 'video_id', 'title', 'channel_title', 'views']].reset_index()
# Out:
#      index  month country     video_id  \
# 0    11214      1      CA  LsoLEjrDogU
# 1    51930      1      DE  LsoLEjrDogU
# 2    92853      1      FR  LsoLEjrDogU
# 3   135208      1      GB  LsoLEjrDogU
# 4   173405      1      IN  dfnCAmr569k
# ..     ...    ...     ...          ...
# 72  166769     12      IN  FlsCjmMhFmw
# 73  224092     12      KR  FlsCjmMhFmw
# 74  259064     12      MX  FlsCjmMhFmw
# 75  299087     12      RU  FlsCjmMhFmw
# 76  341174     12      US  FlsCjmMhFmw
#
#                                                 title      channel_title  \
# 0   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...         Bruno Mars
# 1   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...         Bruno Mars
# 2   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...         Bruno Mars
# 3   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...         Bruno Mars
# 4      Taylor Swift - End Game ft. Ed Sheeran, Future    TaylorSwiftVEVO
# ..                                                ...                ...
# 72  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 73  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 74  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 75  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 76  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
#
#         views
# 0    43067983
# 1    37728802
# 2    37728802
# 3    90598955
# 4    42019590
# ..        ...
# 72  125432237
# 73  113876217
# 74  100912384
# 75   52611730
# 76  149376127
#
# [77 rows x 7 columns]

# %% [markdown]
# **14. Read all json files with the video categories**

# %%
import json

# %%
from pathlib import Path

# %%
import pandas as pd

# %%
categories_folder = Path("../catagories")

# %%
json_files = sorted(categories_folder.glob("*_category_id.json"))
print("Found files:", [p.name for p in json_files])
# Out:
# Found files: ['CA_category_id.json', 'DE_category_id.json', 'FR_category_id.json', 'GB_category_id.json', 'IN_category_id.json', 'JP_category_id.json', 'KR_category_id.json', 'MX_category_id.json', 'RU_category_id.json', 'US_category_id.json']

# %%
json_files
# Out:
# [PosixPath('../catagories/CA_category_id.json'),
#  PosixPath('../catagories/DE_category_id.json'),
#  PosixPath('../catagories/FR_category_id.json'),
#  PosixPath('../catagories/GB_category_id.json'),
#  PosixPath('../catagories/IN_category_id.json'),
#  PosixPath('../catagories/JP_category_id.json'),
#  PosixPath('../catagories/KR_category_id.json'),
#  PosixPath('../catagories/MX_category_id.json'),
#  PosixPath('../catagories/RU_category_id.json'),
#  PosixPath('../catagories/US_category_id.json')]

# %%
dfs = []

# %%
for jf in json_files:
    country = jf.stem.split("_")[0].upper()  # CA_category_id -> CA

    with open(jf, "r", encoding="utf-8") as f:
        data = json.load(f)
        
    items = data.get("items", [])
    
    cat_df = pd.json_normalize(items)

    cat_df = cat_df[["id", "snippet.title", "snippet.assignable"]].rename(columns={
        "id": "category_id",
        "snippet.title": "category_name",
        "snippet.assignable": "assignable"
    })

    cat_df["category_id"] = cat_df["category_id"].astype(str)
    cat_df["country"] = country

    dfs.append(cat_df)

# %%
categories_df = pd.concat(dfs, ignore_index=True)
categories_df.head()
# Out:
#   category_id     category_name  assignable country
# 0           1  Film & Animation        True      CA
# 1           2  Autos & Vehicles        True      CA
# 2          10             Music        True      CA
# 3          15    Pets & Animals        True      CA
# 4          17            Sports        True      CA

# %%
categories_df['country'].unique()
# Out:
# array(['CA', 'DE', 'FR', 'GB', 'IN', 'JP', 'KR', 'MX', 'RU', 'US'],
#       dtype=object)

# %% [markdown]
# **15. For each country, determine how many videos have a category that is not assignable.**

# %%
df["category_id"] = df["category_id"].astype(str)
categories_df["category_id"] = categories_df["category_id"].astype(str)

# %%
df_merged = df.merge(
    categories_df[["country", "category_id", "assignable"]],
    on=["country", "category_id"],
    how="left"
)

# %%
df_merged
# Out:
#             video_id trending_date  \
# 0        n1WpP7iowLc    2017-11-14
# 1        n1WpP7iowLc    2017-11-14
# 2        0dBIkQ4Mz1M    2017-11-14
# 3        0dBIkQ4Mz1M    2017-11-14
# 4        5qpjK5DgCt4    2017-11-14
# ...              ...           ...
# 1487915  D6Oy4LfoqsU    2018-06-14
# 1487916  oV0zkMe1K8s    2018-06-14
# 1487917  oV0zkMe1K8s    2018-06-14
# 1487918  ooyjaVdt-jA    2018-06-14
# 1487919  ooyjaVdt-jA    2018-06-14
#
#                                                      title  \
# 0               Eminem - Walk On Water (Audio) ft. Beyoncé
# 1               Eminem - Walk On Water (Audio) ft. Beyoncé
# 2                            PLUSH - Bad Unboxing Fan Mail
# 3                            PLUSH - Bad Unboxing Fan Mail
# 4        Racist Superman | Rudy Mancuso, King Bach & Le...
# ...                                                    ...
# 1487915  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 1487916                How Black Panther Should Have Ended
# 1487917                How Black Panther Should Have Ended
# 1487918  Official Call of Duty®: Black Ops 4 — Multipla...
# 1487919  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                     channel_title category_id              publish_time  \
# 0                      EminemVEVO          10 2017-11-10 17:00:03+00:00
# 1                      EminemVEVO          10 2017-11-10 17:00:03+00:00
# 2                       iDubbbzTV          23 2017-11-13 17:00:00+00:00
# 3                       iDubbbzTV          23 2017-11-13 17:00:00+00:00
# 4                    Rudy Mancuso          23 2017-11-12 19:05:24+00:00
# ...                           ...         ...                       ...
# 1487915                Brad Mondo          24 2018-05-18 17:34:22+00:00
# 1487916  How It Should Have Ended           1 2018-05-17 17:00:04+00:00
# 1487917  How It Should Have Ended           1 2018-05-17 17:00:04+00:00
# 1487918              Call of Duty          20 2018-05-17 17:09:38+00:00
# 1487919              Call of Duty          20 2018-05-17 17:09:38+00:00
#
#                                                       tags     views   likes  \
# 0        Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1        Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 2        plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
# 3        plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
# 4        racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146035
# ...                                                    ...       ...     ...
# 1487915  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 1487916  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 1487917  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 1487918      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
# 1487919      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#          dislikes  ...  video_error_or_removed  \
# 0           43420  ...                   False
# 1           43420  ...                   False
# 2            1688  ...                   False
# 3            1688  ...                   False
# 4            5339  ...                   False
# ...           ...  ...                     ...
# 1487915      1032  ...                   False
# 1487916      2846  ...                   False
# 1487917      2846  ...                   False
# 1487918    212976  ...                   False
# 1487919    212976  ...                   False
#
#                                                description  country  \
# 0        Eminem's new track Walk on Water ft. Beyoncé i...       CA
# 1        Eminem's new track Walk on Water ft. Beyoncé i...       CA
# 2        STill got a lot of packages. Probably will las...       CA
# 3        STill got a lot of packages. Probably will las...       CA
# 4        WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...       CA
# ...                                                    ...      ...
# 1487915  I had so much fun transforming Safiyas hair in...       US
# 1487916  How Black Panther Should Have EndedWatch More ...       US
# 1487917  How Black Panther Should Have EndedWatch More ...       US
# 1487918  Call of Duty: Black Ops 4 Multiplayer raises t...       US
# 1487919  Call of Duty: Black Ops 4 Multiplayer raises t...       US
#
#          like_ratio  cluster  \
# 0         18.135076      102
# 1         18.135076      102
# 2         75.707346      102
# 3         75.707346      102
# 4         27.352500      114
# ...             ...      ...
# 1487915   46.577519      105
# 1487916   67.799368      102
# 1487917   67.799368      102
# 1487918    1.676616      102
# 1487919    1.676616      102
#
#                                                   tag_list  year  day  month  \
# 0        [Eminem, "Walk", "On", "Water", "Aftermath/Sha...  2017   14     11
# 1        [Eminem, "Walk", "On", "Water", "Aftermath/Sha...  2017   14     11
# 2        [plush, "bad unboxing", "unboxing", "fan mail"...  2017   14     11
# 3        [plush, "bad unboxing", "unboxing", "fan mail"...  2017   14     11
# 4        [racist superman, "rudy", "mancuso", "king", "...  2017   14     11
# ...                                                    ...   ...  ...    ...
# 1487915  [I gave safiya nygaard a perfect hair makeover...  2018   14      6
# 1487916  [Black Panther, "HISHE", "Marvel", "Infinity W...  2018   14      6
# 1487917  [Black Panther, "HISHE", "Marvel", "Infinity W...  2018   14      6
# 1487918  [call of duty, "cod", "activision", "Black Ops...  2018   14      6
# 1487919  [call of duty, "cod", "activision", "Black Ops...  2018   14      6
#
#         assignable
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ...            ...
# 1487915       True
# 1487916       True
# 1487917       True
# 1487918       True
# 1487919       True
#
# [1487920 rows x 24 columns]

# %%
not_assignable_df = df_merged[df_merged["assignable"] == False]
not_assignable_df.shape
# Out:
# (4060, 24)

# %%
result = (
    not_assignable_df
    .groupby("country")
    .size()
    .reset_index(name="num_videos_not_assignable")
    .sort_values("num_videos_not_assignable", ascending=False)
)
result
# Out:
#   country  num_videos_not_assignable
# 4      IN                        884
# 7      RU                        780
# 5      KR                        668
# 0      CA                        520
# 2      FR                        448
# 1      DE                        440
# 8      US                        228
# 3      GB                         80
# 6      MX                         12

# %%
result_all = (
    df_merged.assign(not_assignable = df_merged["assignable"] == False)
    .groupby("country")["not_assignable"]
    .sum()
    .reset_index(name="num_videos_not_assignable")
    .sort_values("num_videos_not_assignable", ascending=False)
)

result_all
# Out:
#   country  num_videos_not_assignable
# 4      IN                        884
# 8      RU                        780
# 6      KR                        668
# 0      CA                        520
# 2      FR                        448
# 1      DE                        440
# 9      US                        228
# 3      GB                         80
# 7      MX                         12
# 5      JP                          0
